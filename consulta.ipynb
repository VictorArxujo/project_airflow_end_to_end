# %%
import pandas as pd
from sqlalchemy import create_engine, text
from pathlib import Path
from dotenv import load_dotenv
import os

load_dotenv(Path().resolve() / 'config' / '.env')

engine = create_engine(
    f"postgresql+psycopg2://{os.getenv('DB_USER')}:{os.getenv('DB_PASSWORD')}"
    f"@{os.getenv('DB_HOST')}:{os.getenv('DB_PORT')}/{os.getenv('DB_NAME')}"
)
print("✅ Conectado!")
# Out:
# ✅ Conectado!

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM weather_current ORDER BY collected_at DESC"))
    df = pd.DataFrame(result.fetchall(), columns=result.keys())

df
# Out:
#    id  city_name country  latitude  longitude  temperature  feels_like  \
# 0   2   Londrina      BR  -23.3103   -51.1628        27.81       28.59
# 1   1  São Paulo      BR  -23.5475   -46.6361        22.67       23.13
#
#    humidity  pressure weather_main weather_desc  wind_speed  \
# 0        54      1016       Clouds      nublado        2.57
# 1        82      1019        Clear    céu limpo        5.14
#
#                     sunrise                    sunset  \
# 0 2026-05-02 09:45:03+00:00 2026-05-02 20:58:04+00:00
# 1 2026-05-02 09:27:14+00:00 2026-05-02 20:39:40+00:00
#
#                       collected_at
# 0 2026-05-02 19:38:40.978582+00:00
# 1 2026-05-02 19:09:58.060874+00:00

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT * FROM weather_forecast ORDER BY collected_at DESC"))
    df = pd.DataFrame(result.fetchall(), columns=result.keys())

df
# Out:
#     id       city_name country  latitude  longitude       forecast_time  \
# 0    1  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-02 21:00:00
# 1    2  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 00:00:00
# 2    3  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 03:00:00
# 3    4  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 06:00:00
# 4    5  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 09:00:00
# 5    6  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 12:00:00
# 6    7  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 15:00:00
# 7    8  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 18:00:00
# 8    9  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-03 21:00:00
# 9   10  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 00:00:00
# 10  11  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 03:00:00
# 11  12  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 06:00:00
# 12  13  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 09:00:00
# 13  14  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 12:00:00
# 14  15  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 15:00:00
# 15  16  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 18:00:00
# 16  17  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-04 21:00:00
# 17  18  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 00:00:00
# 18  19  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 03:00:00
# 19  20  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 06:00:00
# 20  21  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 09:00:00
# 21  22  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 12:00:00
# 22  23  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 15:00:00
# 23  24  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 18:00:00
# 24  25  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-05 21:00:00
# 25  26  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 00:00:00
# 26  27  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 03:00:00
# 27  28  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 06:00:00
# 28  29  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 09:00:00
# 29  30  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 12:00:00
# 30  31  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 15:00:00
# 31  32  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 18:00:00
# 32  33  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-06 21:00:00
# 33  34  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 00:00:00
# 34  35  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 03:00:00
# 35  36  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 06:00:00
# 36  37  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 09:00:00
# 37  38  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 12:00:00
# 38  39  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 15:00:00
# 39  40  Rio de Janeiro      BR  -22.9028   -43.2075 2026-05-07 18:00:00
#
#     temperature  feels_like  humidity  pressure weather_main  \
# 0         28.80       33.02        74      1014       Clouds
# 1         27.92       30.77        72      1014       Clouds
# 2         28.25       31.16        70      1015       Clouds
# 3         26.80       28.90        75      1016       Clouds
# 4         26.78       29.34        81      1017         Rain
# 5         23.88       24.67        90      1020         Rain
# 6         21.95       22.45        86      1020         Rain
# 7         20.58       21.04        90      1020         Rain
# 8         21.01       21.33        83      1021         Rain
# 9         21.14       21.42        81      1022         Rain
# 10        21.03       21.28        80      1022         Rain
# 11        20.67       20.99        84      1020         Rain
# 12        20.06       20.42        88      1021         Rain
# 13        21.92       22.15        76      1022       Clouds
# 14        24.17       24.34        65      1021       Clouds
# 15        23.85       24.07        68      1019       Clouds
# 16        22.96       23.14        70      1020       Clouds
# 17        21.49       21.65        75      1020       Clouds
# 18        20.84       21.02        78      1020       Clouds
# 19        20.22       20.44        82      1019       Clouds
# 20        19.96       20.15        82      1019        Clear
# 21        23.54       23.73        68      1020        Clear
# 22        27.94       29.05        57      1019        Clear
# 23        27.49       28.91        62      1017        Clear
# 24        24.53       25.08        78      1018        Clear
# 25        24.06       24.61        80      1019       Clouds
# 26        23.76       24.20        77      1019       Clouds
# 27        22.81       23.24        80      1018       Clouds
# 28        22.11       22.47        80      1018        Clear
# 29        25.38       25.72        67      1020        Clear
# 30        28.98       30.14        54      1018        Clear
# 31        28.31       29.68        58      1016        Clear
# 32        25.07       25.67        78      1016       Clouds
# 33        24.48       25.10        81      1017         Rain
# 34        23.49       24.09        84      1017         Rain
# 35        22.53       23.08        86      1016        Clear
# 36        21.79       22.22        84      1016        Clear
# 37        25.00       25.41        71      1017        Clear
# 38        29.20       30.46        54      1015        Clear
# 39        28.95       30.37        56      1013        Clear
#
#         weather_desc  wind_speed   pop                     collected_at
# 0            nublado        1.12  0.00 2026-05-02 19:44:54.813607+00:00
# 1            nublado        0.69  0.00 2026-05-02 19:44:54.813607+00:00
# 2            nublado        0.95  0.00 2026-05-02 19:44:54.813607+00:00
# 3            nublado        2.28  0.00 2026-05-02 19:44:54.813607+00:00
# 4         chuva leve        2.44  0.90 2026-05-02 19:44:54.813607+00:00
# 5     chuva moderada        3.59  1.00 2026-05-02 19:44:54.813607+00:00
